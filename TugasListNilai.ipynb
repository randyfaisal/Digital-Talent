# %%
import random

# GENERATE RANDOM
nilaiTugas = []

for i in range(250):
    nilaiTugas.append(random.randrange(1,100,1))
print(nilaiTugas)
    #Menghitung Ganjil
for n in nilaiTugas:
    if (nilaiTugas[n]%2)!=0:
        print("Ganjil", nilaiTugas[n])
# Out:
# [95, 71, 93, 65, 4, 57, 57, 95, 65, 33, 37, 45, 54, 7, 12, 31, 78, 40, 75, 30, 95, 44, 5, 64, 46, 76, 64, 95, 1, 29, 12, 90, 47, 62, 33, 8, 52, 61, 95, 9, 20, 42, 71, 25, 63, 99, 97, 16, 27, 18, 11, 94, 77, 64, 46, 80, 51, 45, 24, 81, 84, 23, 41, 11, 5, 7, 49, 18, 34, 4, 85, 71, 3, 5, 47, 91, 35, 31, 2, 39, 42, 75, 67, 22, 38, 81, 94, 76, 90, 75, 88, 79, 67, 30, 24, 81, 24, 73, 83, 25, 32, 62, 47, 79, 30, 41, 99, 62, 87, 1, 72, 26, 47, 52, 66, 37, 75, 80, 36, 82, 70, 39, 22, 25, 46, 94, 3, 20, 62, 47, 82, 16, 42, 19, 88, 25, 3, 9, 15, 94, 96, 33, 52, 54, 72, 37, 33, 69, 5, 25, 40, 83, 50, 89, 25, 44, 88, 23, 94, 77, 5, 19, 42, 1, 70, 37, 23, 51, 7, 75, 97, 69, 89, 71, 74, 54, 55, 68, 3, 13, 57, 83, 25, 23, 20, 50, 25, 54, 97, 26, 46, 34, 9, 49, 96, 38, 96, 24, 5, 36, 82, 24, 10, 61, 28, 76, 18, 15, 7, 19, 91, 31, 34, 55, 39, 34, 27, 25, 38, 42, 43, 8, 98, 20, 41, 80, 28, 80, 97, 51, 7, 89, 94, 89, 53, 54, 64, 93, 15, 6, 87, 20, 30, 58, 13, 45, 50, 58, 4, 65]
# Ganjil 81
# Ganjil 71
# Ganjil 7
# Ganjil 45
# Ganjil 45
# Ganjil 81
# Ganjil 7
# Ganjil 61
# Ganjil 99
# Ganjil 95
# Ganjil 91
# Ganjil 81
# Ganjil 63
# Ganjil 57
# Ganjil 5
# Ganjil 97
# Ganjil 35
# Ganjil 5
# Ganjil 81
# Ganjil 71
# Ganjil 29
# Ganjil 41
# Ganjil 65
# Ganjil 77
# Ganjil 23
# Ganjil 81
# Ganjil 33
# Ganjil 95
# Ganjil 71
# Ganjil 71
# Ganjil 11
# Ganjil 25
# Ganjil 73
# Ganjil 95
# Ganjil 75
# Ganjil 45
# Ganjil 31
# Ganjil 5
# Ganjil 97
# Ganjil 99
# Ganjil 75
# Ganjil 45
# Ganjil 57
# Ganjil 95
# Ganjil 75
# Ganjil 33
# Ganjil 81
# Ganjil 71
# Ganjil 65
# Ganjil 57
# Ganjil 79
# Ganjil 93
# Ganjil 9
# Ganjil 71
# Ganjil 91
# Ganjil 5
# Ganjil 95
# Ganjil 75
# Ganjil 35
# Ganjil 91
# Ganjil 39
# Ganjil 75
# Ganjil 5
# Ganjil 47
# Ganjil 41
# Ganjil 39
# Ganjil 25
# Ganjil 41
# Ganjil 71
# Ganjil 3
# Ganjil 77
# Ganjil 49
# Ganjil 61
# Ganjil 91
# Ganjil 67
# Ganjil 85
# Ganjil 9
# Ganjil 5
# Ganjil 97
# Ganjil 65
# Ganjil 95
# Ganjil 41
# Ganjil 67
# Ganjil 71
# Ganjil 65
# Ganjil 33
# Ganjil 31
# Ganjil 77
# Ganjil 3
# Ganjil 61
# Ganjil 57
# Ganjil 11
# Ganjil 75
# Ganjil 63
# Ganjil 31
# Ganjil 57
# Ganjil 71
# Ganjil 71
# Ganjil 85
# Ganjil 61
# Ganjil 95
# Ganjil 91
# Ganjil 73
# Ganjil 75
# Ganjil 71
# Ganjil 47
# Ganjil 65
# Ganjil 7
# Ganjil 45
# Ganjil 95
# Ganjil 11
# Ganjil 73
# Ganjil 97
# Ganjil 33
# Ganjil 33
# Ganjil 95
# Ganjil 57
# Ganjil 67
# Ganjil 37
# Ganjil 23
# Ganjil 1
# Ganjil 35
# Ganjil 75
# Ganjil 31
# Ganjil 95
# Ganjil 79
# Ganjil 33
# Ganjil 9
# Ganjil 33
# Ganjil 95
# Ganjil 95
# Ganjil 71
# Ganjil 25
# Ganjil 65
# Ganjil 83
# Ganjil 95
# Ganjil 1
# Ganjil 73
# Ganjil 95
# Ganjil 75
# Ganjil 75
# Ganjil 5
# Ganjil 31
# Ganjil 57
# Ganjil 95
# Ganjil 7
# Ganjil 99
# Ganjil 11
# Ganjil 7

# %%
import random

# GENERATE RANDOM
nilaiTugas = []

#Menampilkan yang lebih Besar dari 70
for i in range(250):
    nilaiTugas.append(random.randrange(1,100,1))
    if(nilaiTugas[i]>70):
        print(nilaiTugas[i])
# Out:
# 82
# 79
# 80
# 91
# 86
# 93
# 90
# 77
# 90
# 71
# 71
# 87
# 94
# 81
# 99
# 98
# 80
# 98
# 92
# 87
# 90
# 89
# 73
# 84
# 75
# 79
# 87
# 85
# 85
# 75
# 86
# 90
# 86
# 85
# 73
# 86
# 71
# 82
# 89
# 79
# 75
# 87
# 92
# 77
# 86
# 96
# 92
# 86
# 94
# 83
# 98
# 74
# 89
# 93
# 84
# 84
# 90
# 84
# 90
# 94
# 92

# %%
import random

# GENERATE RANDOM
nilaiTugas = []
max = 0
min = 0
for i in range(250):
    nilaiTugas.append(random.randrange(1,100,1))
print(nilaiTugas)
    #Menampilkan Nilai Max
for i in nilaiTugas:
    if i > max:
        max=i
print(max) 
    
    #Menampilkan Nilai Min
for i in nilaiTugas:
    if i < max:
        max=i
print(max)
# Out:
# [86, 48, 74, 8, 64, 48, 74, 90, 13, 73, 70, 86, 78, 12, 90, 17, 45, 45, 94, 60, 7, 90, 42, 49, 97, 13, 12, 79, 8, 32, 38, 49, 40, 13, 12, 31, 93, 90, 60, 95, 83, 21, 84, 37, 32, 51, 32, 48, 37, 33, 62, 90, 59, 59, 91, 10, 66, 62, 92, 95, 51, 44, 59, 6, 44, 52, 40, 33, 50, 22, 44, 58, 98, 7, 83, 89, 76, 38, 70, 18, 97, 54, 25, 39, 36, 40, 37, 26, 25, 96, 75, 38, 74, 59, 61, 48, 87, 26, 7, 93, 33, 78, 38, 4, 47, 36, 62, 5, 91, 46, 14, 27, 8, 11, 64, 65, 54, 42, 85, 60, 9, 55, 23, 28, 31, 99, 30, 57, 69, 1, 3, 87, 1, 23, 60, 96, 15, 16, 29, 60, 56, 2, 12, 82, 54, 47, 89, 18, 73, 60, 22, 17, 76, 67, 9, 94, 95, 91, 82, 26, 97, 66, 25, 43, 4, 56, 34, 50, 58, 57, 51, 32, 99, 62, 7, 45, 88, 74, 2, 88, 61, 39, 14, 45, 97, 63, 25, 87, 19, 10, 23, 37, 14, 29, 21, 11, 9, 12, 21, 57, 46, 78, 81, 56, 7, 36, 19, 55, 86, 90, 5, 12, 21, 4, 58, 82, 30, 12, 50, 61, 80, 23, 66, 98, 69, 80, 32, 96, 47, 16, 54, 75, 77, 86, 59, 55, 7, 46, 83, 30, 17, 12, 60, 1, 24, 78, 7, 79, 44, 16]
# 99
# 1

# %%
for i in range(len(nilaiTugas)):
    nilaiTugas[i]=int(nilaiTugas[i])
jumlah=0
for i in range(len(nilaiTugas)):
    jumlah +=nilaiTugas[i]

rata=jumlah/len(nilaiTugas)
sigma = 0
for i in range(len(nilaiTugas)):
    hitung =(nilaiTugas[i]-rata)**2
    sigma += hitung

pembagianN=sigma/len(nilaiTugas)
standarDeviasi=pembagianN ** 0.5
print(standarDeviasi)
# Out:
# 28.842591839153425

# %%
#Menghitung Modus
nilai_modus=nilaiTugas [0]
jumlah=nilaiTugas.count(nilai_modus)
for n in nilaiTugas:
    jumlah_n=nilaiTugas.count (n)
    if jumlah_n>jumlah:
        nilai_modus=n
        jumlah=jumlah_n
print (nilai_modus)
# Out:
# 12
